# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/piotr/Downloads/E-COM DATA/International sale Report.csv')

# %%
df.head(15)
# Out:
#     index      DATE  Months            CUSTOMER    Style             SKU Size  \
# 0       0  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004    MEN5004-KR-L    L
# 1       1  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004   MEN5004-KR-XL   XL
# 2       2  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004  MEN5004-KR-XXL  XXL
# 3       3  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5009    MEN5009-KR-L    L
# 4       4  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5011    MEN5011-KR-L    L
# 5       5  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5025    MEN5025-KR-L    L
# 6       6  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5015   MEN5015-KR-XL   XL
# 7       7  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5022  MEN5022-KR-XXL  XXL
# 8       8  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5014    MEN5014-KR-S    S
# 9       9  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5013    MEN5013-KR-S    S
# 10     10  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5013  MEN5013-KR-XXL  XXL
# ...

# %%
df.tail(15)
# Out:
#        index    DATE    Months CUSTOMER     Style               SKU  Size  \
# 37417  37417  AVIN    03-31-22   Mar-22    SET397   SET397-KR-NP-XL  1.00
# 37418  37418  AVIN    03-31-22   Mar-22    SET268    SET268-KR-NP-S  1.00
# 37419  37419  AVIN    03-31-22   Mar-22   JNE3786   JNE3786-KR-XXXL  1.00
# 37420  37420  AVIN    03-31-22   Mar-22   JNE3313    JNE3313-KR-XXL  1.00
# 37421  37421  AVIN    03-31-22   Mar-22    SET356    SET356-KR-NP-M  2.00
# 37422  37422  AVIN    03-31-22   Mar-22    SET374  SET374-KR-NP-XXL  1.00
# 37423  37423  AVIN    03-31-22   Mar-22    SET339  SET339-KR-NP-XXL  1.00
# 37424  37424  AVIN    03-31-22   Mar-22    SET375  SET375-KR-NP-XXL  1.00
# 37425  37425  AVIN    03-31-22   Mar-22    SET325    SET325-KR-NP-S  1.00
# 37426  37426  AVIN    03-31-22   Mar-22    SET276    SET276-KR-PP-L  1.00
# 37427  37427  AVIN    03-31-22   Mar-22  PJNE3423   PJNE3423-KR-4XL  1.00
# 37428  37428  AVIN    03-31-22   Mar-22  PJNE3404   PJNE3404-KR-4XL  1.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36392 entries, 0 to 37431
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      36392 non-null  int64
#  1   DATE       36392 non-null  object
#  2   Months     36392 non-null  object
#  3   CUSTOMER   36392 non-null  object
#  4   Style      36392 non-null  object
#  5   SKU        34958 non-null  object
#  6   Size       36392 non-null  object
#  7   PCS        36392 non-null  object
#  8   RATE       36392 non-null  object
#  9   GROSS AMT  36392 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.1+ MB

# %%
df.isna().sum()
# Out:
# index           0
# DATE            1
# Months         25
# CUSTOMER     1040
# Style        1040
# SKU          2474
# Size         1040
# PCS          1040
# RATE         1040
# GROSS AMT    1040
# dtype: int64

# %%
df['CUSTOMER'].unique().tolist()
# Out:
# ['REVATHY LOGANATHAN',
#  'FARIA ESSOPP',
#  'MANGALAM SHOP',
#  'THANA NAGISSWARY L MARIMUTHU',
#  'MR.ALWAR MURALI',
#  'RAZIA ROSEANE NASER',
#  'SIRI PADALA',
#  'FUSION FASHIONS CORP.',
#  'MIZNA WAHEEDH',
#  'AMANI CONCEPT TRADING LLC (KAPDA)',
#  'NITHARSHA',
#  'SYEDA MORSHED',
#  'VINTAGE INDIA NYC',
#  'M/S CHARISMAKURTIES(DUBAI)',
#  'MULBERRIES BOUTIQUE',
#  'COTTON CLOSET LTD',
#  'THANA MARIMUTHU',
#  'SHWETA',
#  'MONIYSHAA',
#  'AANCHOL',
#  'KHUSBOO BEEHARRY',
#  'ARUNA DEVI',
#  'YAMUNAH PUSPANATHAN',
#  'RISHIKESH DASHPUTRE',
#  'REGA',
#  'SURE FASHIONS LLC',
#  'MR ALWAR MURALI',
#  'KOGILA SELLAPPAN',
#  'MONISYAA',
#  'VINODHA PUSPANATHAN',
#  'REKA RASAKODY',
#  'ARKH FASHION',
#  'PUVANES GANNASIN',
#  'VINI’S AUTHENTIC INDIAN ETHNIC WEAR',
#  'BINCY SKARIA',
#  'YASHWINI REDDY',
#  'BANUJA RASAKODY',
#  'VAHLAARMATHY',
#  'AKASH KAUSHAL',
#  'KIRUTHIKA V SURESHBABU',
#  'RIVAAN LLC',
#  'SINDHU',
#  'DHENOOGA RAVINTHERAN',
#  'VAHARSHA BOUTIQUE',
# ...

# %%
list_errors=['Months',
 'Jun-21',
 'Jul-21',
 'Aug-21',
 'Sep-21',
 'Oct-21',
 'Nov-21',
 'Dec-21',
 'Jan-22',
 'Feb-22',
 'Mar-22']

# %%
df_customer_nan = df[df['CUSTOMER'].isna()]
df_customer_nan[df_customer_nan["GROSS AMT"].isna()]
# Out:
# Empty DataFrame
# Columns: [index, DATE, Months, CUSTOMER, Style, SKU, Size, PCS, RATE, GROSS AMT]
# Index: []

# %%
df.dropna(subset=["CUSTOMER"],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36392 entries, 0 to 37431
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      36392 non-null  int64
#  1   DATE       36392 non-null  object
#  2   Months     36392 non-null  object
#  3   CUSTOMER   36392 non-null  object
#  4   Style      36392 non-null  object
#  5   SKU        34958 non-null  object
#  6   Size       36392 non-null  object
#  7   PCS        36392 non-null  object
#  8   RATE       36392 non-null  object
#  9   GROSS AMT  36392 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.1+ MB

# %%
df.isna().sum()
# Out:
# index           0
# DATE            0
# Months          0
# CUSTOMER        0
# Style           0
# SKU          1434
# Size            0
# PCS             0
# RATE            0
# GROSS AMT       0
# dtype: int64

# %%
len(df)
# Out:
# 36392
