# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from dotenv import dotenv_values

# %%
data_amazon = pd.read_csv('../data/Amazon_Sales_Clean.csv')
data_international = pd.read_csv('../data/International_Sale_Report.csv')
data_sales = pd.read_csv('../data/Sales_Report.csv')
# Out:
# C:\Users\piotr\AppData\Local\Temp\ipykernel_15180\1520313042.py:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_amazon = pd.read_csv('../data/Amazon_Sales_Clean.csv')

# %%
data_amazon
# Out:
#                    order_id        date                        status  \
# 0       405-8078784-5731545  2022-04-30                     Cancelled
# 1       171-9198151-1101146  2022-04-30  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  2022-04-30                       Shipped
# 3       403-9615377-8133951  2022-04-30                     Cancelled
# 4       407-1069790-7240320  2022-04-30                       Shipped
# ...                     ...         ...                           ...
# 128970  406-6001380-7673107  2022-05-31                       Shipped
# 128971  402-9551604-7544318  2022-05-31                       Shipped
# 128972  407-9547469-3152358  2022-05-31                       Shipped
# 128973  402-6184140-0545956  2022-05-31                       Shipped
# 128974  408-7436540-8728312  2022-05-31                       Shipped
#
#        fulfilment sales_channel_ ship_service_level    style              sku  \
# 0        Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1        Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2          Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3        Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4          Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
# ...           ...            ...                ...      ...              ...
# 128970     Amazon      Amazon.in          Expedited  JNE3697    JNE3697-KR-XL
# 128971     Amazon      Amazon.in          Expedited   SET401   SET401-KR-NP-M
# 128972     Amazon      Amazon.in          Expedited    J0157     J0157-DR-XXL
# 128973     Amazon      Amazon.in          Expedited    J0012     J0012-SKD-XS
# 128974     Amazon      Amazon.in          Expedited    J0003      J0003-SET-S
#
#              category size  ... currency   amount    ship_city    ship_state  \
# 0                 Set    S  ...      INR   647.62       MUMBAI   MAHARASHTRA
# 1               kurta  3XL  ...      INR   406.00    BENGALURU     KARNATAKA
# 2               kurta   XL  ...      INR   329.00  NAVI MUMBAI   MAHARASHTRA
# 3       Western Dress    L  ...      INR   753.33   PUDUCHERRY    PUDUCHERRY
# 4                 Top  3XL  ...      INR   574.00      CHENNAI    TAMIL NADU
# ...               ...  ...  ...      ...      ...          ...           ...
# 128970          kurta   XL  ...      INR   517.00    HYDERABAD     TELANGANA
# 128971            Set    M  ...      INR   999.00     GURUGRAM       HARYANA
# 128972  Western Dress  XXL  ...      INR   690.00    HYDERABAD     TELANGANA
# 128973            Set   XS  ...      INR  1199.00        HALOL       GUJARAT
# 128974            Set    S  ...      INR   696.00       RAIPUR  CHHATTISGARH
#
#         ship_postal_code ship_country  \
# 0               400081.0           IN
# 1               560085.0           IN
# 2               410210.0           IN
# 3               605008.0           IN
# 4               600073.0           IN
# ...                  ...          ...
# 128970          500013.0           IN
# 128971          122004.0           IN
# 128972          500049.0           IN
# 128973          389350.0           IN
# 128974          492014.0           IN
#
#                                             promotion_ids    b2b fulfilled_by  \
# 0                                                     NaN  False    Easy Ship
# 1       Amazon PLCC Free-Financing Universal Merchant ...  False    Easy Ship
# 2            IN Core Free Shipping 2015/04/08 23-48-5-108   True          NaN
# 3                                                     NaN  False    Easy Ship
# 4                                                     NaN  False          NaN
# ...                                                   ...    ...          ...
# 128970                                                NaN  False          NaN
# 128971       IN Core Free Shipping 2015/04/08 23-48-5-108  False          NaN
# 128972                                                NaN  False          NaN
# 128973       IN Core Free Shipping 2015/04/08 23-48-5-108  False          NaN
# 128974       IN Core Free Shipping 2015/04/08 23-48-5-108  False          NaN
#
#        unnamed_22
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 128970      False
# 128971      False
# 128972      False
# 128973      False
# 128974      False
#
# [128975 rows x 23 columns]

# %%
data_amazon['date'] = pd.to_datetime(data_amazon['date'])

# %%
data_amazon['sales_channel_'].unique()
# Out:
# array(['Amazon.in', 'Non-Amazon'], dtype=object)

# %%
data_amazon['fulfilment'].unique()
# Out:
# array(['Merchant', 'Amazon'], dtype=object)

# %%
data_amazon.describe()
# Out:
#                                 date            qty         amount  \
# count                         128975  128975.000000  121180.000000
# mean   2022-05-12 11:49:27.951928576       0.904431     648.561465
# min              2022-03-31 00:00:00       0.000000       0.000000
# 25%              2022-04-20 00:00:00       1.000000     449.000000
# 50%              2022-05-10 00:00:00       1.000000     605.000000
# 75%              2022-06-04 00:00:00       1.000000     788.000000
# max              2022-06-29 00:00:00      15.000000    5584.000000
# std                              NaN       0.313354     281.211687
#
#        ship_postal_code
# count     128942.000000
# mean      463966.236509
# min       110001.000000
# 25%       382421.000000
# 50%       500033.000000
# 75%       600024.000000
# max       989898.000000
# std       191476.764941

# %%
data_international.drop(columns=['Unnamed: 0'], axis = 0, inplace=True)

# %%
data_international
# Out:
#        index      date  months            customer     style              sku  \
# 0          0  06-05-21  Jun-21  REVATHY LOGANATHAN   MEN5004     MEN5004-KR-L
# 1          1  06-05-21  Jun-21  REVATHY LOGANATHAN   MEN5004    MEN5004-KR-XL
# 2          2  06-05-21  Jun-21  REVATHY LOGANATHAN   MEN5004   MEN5004-KR-XXL
# 3          3  06-05-21  Jun-21  REVATHY LOGANATHAN   MEN5009     MEN5009-KR-L
# 4          4  06-05-21  Jun-21  REVATHY LOGANATHAN   MEN5011     MEN5011-KR-L
# ...      ...       ...     ...                 ...       ...              ...
# 35878  37426  03-31-22  Mar-22                AVIN    SET276   SET276-KR-PP-L
# 35879  37427  03-31-22  Mar-22                AVIN  PJNE3423  PJNE3423-KR-4XL
# 35880  37428  03-31-22  Mar-22                AVIN  PJNE3404  PJNE3404-KR-4XL
# 35881  37429  03-31-22  Mar-22                AVIN  PJNE3423  PJNE3423-KR-4XL
# 35882  37430  03-31-22  Mar-22                AVIN    SET290  SET290-KR-DPT-M
#
#       size  pcs     rate  gross_amt
# 0        L  1.0   616.56      617.0
# 1       XL  1.0   616.56      617.0
# 2      XXL  1.0   616.56      617.0
# 3        L  1.0   616.56      617.0
# 4        L  1.0   616.56      617.0
# ...    ...  ...      ...        ...
# 35878    L  1.0  1425.00     1425.0
# 35879  4XL  1.0   537.50      538.0
# 35880  4XL  1.0   500.00      500.0
# 35881  4XL  1.0   537.50      538.0
# 35882    M  1.0   812.50      812.0
#
# [35883 rows x 10 columns]

# %%
data_international['months'].unique()
# Out:
# array(['Jun-21', 'Jul-21', 'Aug-21', 'Sep-21', 'Oct-21', 'Nov-21',
#        'Dec-21', 'Jan-22', 'Feb-22', 'Mar-22', 'Apr-22', 'May-22'],
#       dtype=object)

# %%
data_sales.drop(columns=["Unnamed: 0"], axis=0, inplace=True)

# %%
data_sales
# Out:
#       index           sku_code design_no_  stock       category  size color
# 0         0        AN201-RED-L      AN201    5.0  AN : LEGGINGS     L   Red
# 1         1        AN201-RED-M      AN201    5.0  AN : LEGGINGS     M   Red
# 2         2        AN201-RED-S      AN201    3.0  AN : LEGGINGS     S   Red
# 3         3       AN201-RED-XL      AN201    6.0  AN : LEGGINGS    XL   Red
# 4         4      AN201-RED-XXL      AN201    3.0  AN : LEGGINGS   XXL   Red
# ...     ...                ...        ...    ...            ...   ...   ...
# 9221   9230     SET462-KR-NP-S     SET462   44.0            SET     S  Teal
# 9222   9231    SET462-KR-NP-XL     SET462   58.0            SET    XL  Teal
# 9223   9232    SET462-KR-NP-XS     SET462   20.0            SET    XS  Teal
# 9224   9233   SET462-KR-NP-XXL     SET462   66.0            SET   XXL  Teal
# 9225   9234  SET462-KR-NP-XXXL     SET462   40.0            SET  XXXL  Teal
#
# [9226 rows x 7 columns]

# %%
config = dotenv_values()

# %%
pg_user = config['POSTGRES_USER']
pg_host = config['POSTGRES_HOST']
pg_port = config['POSTGRES_PORT']
pg_db = config['POSTGRES_DB']
pg_schema = config['POSTGRES_SCHEMA']
pg_pass = config['POSTGRES_PASS']

# %% [markdown]
# ```python
# url = '<dialect>://<user>:<password>@<host>:<port>/<database>?currentSchema={schema}'
# ```

# %%
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'
engine = create_engine(url, echo = False)

# %%
engine.url
# Out:
# postgresql://postgres:***@localhost:5432/postgres

# %%
data_amazon.to_sql(
    name="Ecom_Data_Amazon",
    con=engine,           
    if_exists="replace",
    index=False
)

# %% [markdown]
# ## Adding cost values to the data

# %%
ecommerce_A_data = pd.read_csv('../data/ecommerce_data.csv')

# %%
ecommerce_A_data
# Out:
#                            date                        status fulfilment  \
# 0       2022-04-15 00:00:00.000  Shipped - Delivered to Buyer   Merchant
# 1       2022-04-15 00:00:00.000                       Shipped     Amazon
# 2       2022-04-15 00:00:00.000                       Shipped     Amazon
# 3       2022-04-15 00:00:00.000                       Shipped     Amazon
# 4       2022-04-15 00:00:00.000                       Shipped     Amazon
# ...                         ...                           ...        ...
# 110532  2022-04-15 00:00:00.000                       Shipped     Amazon
# 110533  2022-04-15 00:00:00.000                       Shipped     Amazon
# 110534  2022-04-13 00:00:00.000                       Shipped     Amazon
# 110535  2022-04-13 00:00:00.000                       Shipped     Amazon
# 110536  2022-04-13 00:00:00.000                       Shipped     Amazon
#
#        sales_channel_  amount  qty       category               size    style  \
# 0           Amazon.in   442.0    1          kurta       JNE3510-KR-M  JNE3510
# 1           Amazon.in   376.0    1          kurta  JNE3366-KR-1053-M  JNE3366
# 2           Amazon.in   471.0    1          kurta       JNE3368-KR-M  JNE3368
# 3           Amazon.in   523.0    1            Set      NW015-TP-PJ-S    NW015
# 4           Amazon.in   788.0    1            Set    SET268-KR-NP-XS   SET268
# ...               ...     ...  ...            ...                ...      ...
# 110532      Amazon.in   612.0    1            Set    SET044-KR-NP-XS   SET044
# 110533      Amazon.in   488.0    1  Western Dress         J0171-DR-M    J0171
# 110534      Amazon.in   399.0    1          kurta      JNE3405-KR-XS  JNE3405
# 110535      Amazon.in   725.0    1  Western Dress      JNE3797-KR-XL  JNE3797
# 110536      Amazon.in   399.0    1          kurta      JNE3405-KR-XS  JNE3405
#
#               ship_city    ship_state  ship_postal_code
# 0                 KORBA  CHHATTISGARH          495450.0
# 1           TIRUNELVELI    TAMIL NADU          627416.0
# 2           TIRUNELVELI    TAMIL NADU          627416.0
# 3                 AJMER     RAJASTHAN          305001.0
# 4             NEW DELHI         DELHI          110019.0
# ...                 ...           ...               ...
# 110532        HYDERABAD     TELANGANA          500084.0
# 110533        HYDERABAD     TELANGANA          500080.0
# 110534           MUMBAI   MAHARASHTRA          400051.0
# 110535  TIRUCHIRAPPALLI    TAMIL NADU          620001.0
# 110536         JHALAWAR     RAJASTHAN          326512.0
#
# [110537 rows x 12 columns]

# %%
style_avg_amount = ecommerce_A_data.groupby("style")["amount"].mean()

# %%
style_avg_amount
# Out:
# style
# AN201      257.800000
# AN202      271.428571
# AN203      301.000000
# AN204      320.571429
# AN205      281.000000
#              ...
# SET445    1399.000000
# SET446    1449.000000
# SET449    1449.000000
# SET461     859.000000
# SET462     999.000000
# Name: amount, Length: 1371, dtype: float64

# %%
style_to_cost = {}
for style, avg in style_avg_amount.items():
    if pd.isna(avg) or avg == 0 :  # pomijaj podejrzane przypadki
        continue
    random_cost = np.random.uniform(0.35 * avg, 0.7 * avg)
    style_to_cost[style] = round(random_cost, 2)

# %%
style_to_cost
# Out:
# {'AN201': 159.01,
#  'AN202': 170.27,
#  'AN203': 123.89,
#  'AN204': 147.08,
#  'AN205': 122.58,
#  'AN206': 192.24,
#  'AN207': 117.45,
#  'AN208': 162.01,
#  'AN209': 112.71,
#  'AN211': 207.26,
#  'AN212': 120.23,
#  'AN213': 167.22,
#  'BL001': 241.4,
#  'BL003': 263.32,
#  'BL004': 163.94,
#  'BL006': 188.03,
#  'BL007': 137.43,
#  'BL008': 177.06,
#  'BL009': 258.87,
#  'BL010': 284.65,
#  'BL011': 174.5,
#  'BL013': 192.35,
#  'BL015': 216.34,
#  'BL016': 227.13,
#  'BL017': 133.65,
#  'BL019': 290.51,
#  'BL020': 166.21,
#  'BL021': 167.48,
#  'BL022': 198.96,
#  'BL023': 150.22,
#  'BL024': 144.92,
#  'BL025': 176.68,
#  'BL026': 244.12,
#  'BL029': 280.4,
#  'BL035': 215.54,
#  'BL036': 279.81,
#  'BL041': 161.81,
#  'BL050': 247.92,
#  'BL053': 168.54,
#  'BL055': 219.57,
#  'BL056': 145.94,
#  'BL057': 198.89,
#  'BL060': 278.67,
#  'BL073': 218.49,
#  'BL074': 292.77,
#  'BL075': 296.1,
#  'BL079': 293.2,
#  'BL085': 197.98,
#  'BL086': 201.81,
#  'BL087': 233.87,
#  'BL089': 160.33,
#  'BL090': 216.33,
#  'BL093': 123.51,
#  'BL095': 208.38,
#  'BL096': 175.46,
#  'BL098': 127.61,
#  'BL099': 138.0,
#  'BL100': 156.09,
#  'BL101': 159.32,
#  'BL102': 93.66,
#  'BL103': 333.48,
#  'BL104': 203.16,
#  'BL107': 160.57,
#  'BL109': 237.02,
#  'BL110': 156.14,
#  'BL111': 121.19,
#  'BL113': 220.11,
#  'BTM002': 244.14,
#  'BTM003': 197.61,
#  'BTM004': 192.99,
#  'BTM005': 188.62,
#  'BTM008': 232.64,
#  'BTM021': 202.39,
#  'BTM026': 266.43,
#  'BTM027': 327.02,
#  'BTM029': 299.02,
#  'BTM030': 114.02,
#  'BTM031': 247.83,
#  'BTM032': 162.18,
#  'BTM033': 115.58,
#  'BTM035': 112.89,
#  'BTM036': 153.42,
#  'BTM037': 212.17,
#  'BTM038': 203.3,
#  'BTM039': 228.3,
#  'BTM040': 223.14,
#  'BTM041': 138.43,
#  'BTM042': 111.52,
#  'BTM043': 202.45,
#  'BTM044': 180.92,
#  'BTM045': 118.61,
#  'BTM046': 80.45,
#  'BTM047': 161.08,
#  'BTM048': 102.12,
#  'CH201': 110.83,
#  'CH202': 135.59,
#  'CH203': 179.1,
#  'CH204': 151.16,
#  'CH205': 148.55,
#  'CH206': 126.72,
#  'CH207': 198.95,
#  'CH208': 151.92,
#  'CH209': 102.65,
#  'CH213': 125.73,
#  'DPT032': 202.93,
#  'DPT041': 181.84,
#  'DPT052': 212.06,
#  'J0001': 405.52,
#  'J0002': 473.68,
#  'J0003': 318.25,
#  'J0004': 436.3,
#  'J0005': 585.14,
#  'J0006': 294.76,
#  'J0007': 514.88,
#  'J0008': 432.5,
#  'J0009': 343.21,
#  'J0010': 460.71,
#  'J0011': 701.48,
#  'J0012': 478.06,
#  'J0013': 593.86,
#  'J0014': 769.07,
#  'J0015': 379.74,
#  'J0016': 270.79,
#  'J0019': 356.47,
#  'J0020': 363.5,
#  'J0021': 210.56,
#  'J0022': 367.41,
#  'J0023': 212.0,
#  'J0024': 171.01,
#  'J0025': 361.87,
#  'J0026': 178.18,
#  'J0027': 348.47,
#  'J0028': 139.05,
#  'J0029': 230.27,
#  'J0033': 148.87,
#  'J0034': 335.47,
#  'J0036': 198.64,
#  'J0037': 252.91,
#  'J0038': 292.44,
#  'J0039': 423.66,
#  'J0040': 383.39,
#  'J0041': 350.39,
#  'J0042': 260.75,
#  'J0043': 336.28,
#  'J0044': 167.41,
#  'J0047': 230.64,
#  'J0048': 192.77,
#  'J0049': 157.63,
#  'J0051': 264.88,
#  'J0052': 359.06,
#  'J0053': 323.5,
#  'J0055': 563.6,
#  'J0057': 188.34,
#  'J0058': 186.55,
#  'J0062': 197.72,
#  'J0070': 210.72,
#  'J0072': 125.61,
#  'J0073': 183.54,
#  'J0074': 115.88,
#  'J0075': 177.31,
#  'J0076': 174.68,
#  'J0077': 534.17,
#  'J0078': 639.05,
#  'J0079': 697.7,
#  'J0080': 298.94,
#  'J0081': 384.18,
#  'J0082': 230.85,
#  'J0083': 176.13,
#  'J0084': 201.29,
#  'J0085': 134.04,
#  'J0086': 335.99,
#  'J0087': 226.82,
#  'J0088': 219.35,
#  'J0089': 154.69,
#  'J0090': 294.34,
#  'J0091': 212.59,
#  'J0092': 361.54,
#  'J0093': 340.16,
#  'J0094': 337.79,
#  'J0095': 344.99,
#  'J0096': 302.2,
#  'J0097': 312.9,
#  'J0098': 211.86,
#  'J0100': 509.86,
#  'J0101': 348.28,
#  'J0102': 503.6,
#  'J0103': 585.55,
#  'J0104': 165.75,
#  'J0105': 598.25,
#  'J0106': 453.59,
#  'J0108': 772.98,
#  'J0109': 502.46,
#  'J0110': 411.51,
#  'J0111': 229.86,
#  'J0112': 138.21,
#  'J0113': 351.05,
#  'J0114': 131.71,
#  'J0115': 167.19,
#  'J0116': 181.1,
#  'J0117': 303.55,
#  'J0118': 285.95,
#  'J0119': 277.56,
#  'J0120': 149.7,
#  'J0121': 114.68,
#  'J0122': 175.54,
#  'J0123': 178.17,
#  'J0124': 339.13,
#  'J0126': 325.11,
#  'J0127': 436.91,
#  'J0129': 278.82,
#  'J0130': 265.94,
#  'J0131': 156.05,
#  'J0132': 133.88,
#  'J0133': 234.14,
#  'J0134': 398.46,
#  'J0135': 287.71,
#  'J0136': 208.96,
#  'J0137': 271.2,
#  'J0138': 204.12,
#  'J0139': 211.37,
#  'J0140': 299.09,
#  'J0141': 244.76,
#  'J0142': 257.84,
#  'J0143': 442.67,
#  'J0144': 283.33,
#  'J0145': 291.35,
#  'J0147': 306.35,
#  'J0148': 397.73,
#  'J0149': 137.11,
#  'J0150': 204.7,
#  'J0151': 223.14,
#  'J0152': 586.88,
#  'J0153': 269.78,
#  'J0154': 187.81,
#  'J0155': 286.99,
#  'J0157': 388.63,
#  'J0158': 359.25,
#  'J0159': 256.79,
#  'J0160': 207.83,
#  'J0161': 315.4,
#  'J0162': 740.67,
#  'J0163': 430.14,
#  'J0164': 220.79,
#  'J0165': 209.7,
#  'J0166': 228.8,
#  'J0167': 126.71,
#  'J0168': 272.0,
#  'J0170': 165.57,
#  'J0171': 228.06,
#  'J0172': 240.64,
#  'J0173': 161.33,
#  'J0174': 254.01,
#  'J0175': 187.58,
#  'J0176': 243.34,
#  'J0177': 145.4,
#  'J0178': 209.61,
#  'J0179': 318.09,
#  'J0180': 242.66,
#  'J0181': 251.15,
#  'J0182': 277.54,
#  'J0183': 187.63,
#  'J0184': 198.29,
#  'J0185': 413.82,
#  'J0186': 351.32,
#  'J0187': 352.76,
#  'J0188': 219.94,
#  'J0189': 126.44,
#  'J0190': 179.84,
#  'J0192': 137.45,
#  'J0193': 464.09,
#  'J0194': 291.35,
#  'J0195': 498.94,
#  'J0196': 236.96,
#  'J0197': 237.25,
#  'J0198': 408.74,
#  'J0199': 192.26,
#  'J0201': 307.31,
#  'J0202': 246.54,
#  'J0203': 235.46,
#  'J0204': 406.47,
#  'J0205': 216.88,
#  'J0207': 352.59,
#  'J0208': 380.3,
#  'J0209': 458.14,
#  'J0210': 497.25,
#  'J0211': 312.56,
#  'J0212': 360.56,
#  'J0213': 283.99,
#  'J0214': 226.53,
#  'J0215': 312.33,
#  'J0216': 297.76,
#  'J0217': 242.04,
#  'J0219': 384.72,
#  'J0220': 349.63,
#  'J0223': 749.09,
#  'J0224': 644.52,
#  'J0225': 603.32,
#  'J0226': 861.17,
#  'J0228': 1128.02,
#  'J0229': 655.43,
#  'J0230': 506.27,
#  'J0231': 630.77,
#  'J0232': 613.88,
#  'J0233': 553.98,
#  'J0234': 738.63,
#  'J0235': 732.74,
#  'J0236': 332.52,
#  'J0237': 622.18,
#  'J0238': 815.01,
#  'J0239': 596.31,
#  'J0240': 938.89,
#  'J0241': 476.45,
#  'J0242': 627.56,
#  'J0243': 426.08,
#  'J0244': 664.68,
#  'J0245': 438.51,
#  'J0246': 479.82,
#  'J0247': 455.63,
#  'J0248': 596.42,
#  'J0249': 306.81,
#  'J0250': 435.07,
#  'J0251': 331.39,
#  'J0252': 334.85,
#  'J0254': 440.36,
#  'J0277': 876.72,
#  'J0278': 368.77,
#  'J0279': 312.38,
#  'J0280': 637.1,
#  'J0281': 460.37,
#  'J0282': 325.22,
#  'J0283': 372.46,
#  'J0284': 529.62,
#  'J0285': 702.42,
#  'J0286': 529.53,
#  'J0290': 309.69,
#  'J0291': 510.55,
#  'J0292': 201.26,
#  'J0293': 231.51,
#  'J0294': 180.55,
#  'J0295': 400.6,
#  'J0296': 181.44,
#  'J0297': 204.13,
#  'J0298': 319.67,
#  'J0299': 198.47,
#  'J0300': 161.04,
#  'J0301': 311.14,
#  'J0302': 271.28,
#  'J0303': 244.11,
#  'J0304': 129.48,
#  'J0305': 433.16,
#  'J0306': 471.98,
#  'J0307': 251.5,
#  'J0308': 429.49,
#  'J0310': 162.25,
#  'J0314': 368.43,
#  'J0319': 477.06,
#  'J0323': 304.36,
#  'J0328': 336.15,
#  'J0329': 331.47,
#  'J0330': 290.81,
#  'J0331': 452.23,
#  'J0332': 480.71,
#  'J0333': 520.71,
#  'J0334': 193.59,
#  'J0335': 567.9,
#  'J0336': 368.39,
#  'J0337': 357.22,
#  'J0338': 563.89,
#  'J0339': 406.27,
#  'J0340': 449.86,
#  'J0341': 292.41,
#  'J0342': 308.71,
#  'J0343': 507.08,
#  'J0344': 367.63,
#  'J0345': 326.34,
#  'J0346': 323.13,
#  'J0347': 253.1,
#  'J0348': 296.54,
#  'J0349': 382.13,
#  'J0350': 210.76,
#  'J0351': 339.52,
#  'J0352': 429.75,
#  'J0353': 227.13,
#  'J0354': 302.68,
#  'J0355': 336.65,
#  'J0369': 556.99,
#  'J0370': 402.76,
#  'J0371': 619.05,
#  'J0372': 509.48,
#  'J0373': 335.47,
#  'J0374': 298.35,
#  'J0375': 442.63,
#  'J0376': 690.35,
#  'J0377': 541.82,
#  'J0378': 679.73,
#  'J0379': 732.03,
#  'J0380': 826.6,
#  'J0381': 420.6,
#  'J0382': 737.84,
#  'J0385': 581.5,
#  'J0386': 373.04,
#  'J0388': 325.85,
#  'J0389': 369.46,
#  'J0390': 434.52,
#  'J0391': 393.84,
#  'J0392': 386.97,
#  'J0395': 573.97,
#  'J0396': 476.11,
#  'J0397': 376.88,
#  'J0398': 387.41,
#  'J0399': 556.27,
#  'J0400': 606.14,
#  'J0401': 513.68,
#  'J0402': 255.68,
#  'J0413': 268.26,
#  'J0414': 476.96,
#  'J0415': 595.66,
#  'J0416': 435.6,
#  'J0417': 493.64,
#  'J0418': 520.59,
#  'J0419': 294.21,
#  'J0420': 376.91,
#  'J0429': 509.71,
#  'J0431': 458.1,
#  'J0434': 406.99,
#  'JNE0722': 447.65,
#  'JNE0850': 320.71,
#  'JNE09186': 381.62,
#  'JNE09187': 297.15,
#  'JNE09209': 509.06,
#  'JNE09210': 503.28,
#  'JNE1000': 421.2,
#  'JNE1233': 220.48,
#  'JNE1234': 170.68,
#  'JNE1407': 247.82,
#  'JNE1408': 125.1,
#  'JNE1525': 126.94,
#  'JNE1906': 215.65,
#  'JNE1951': 204.24,
#  'JNE1975': 103.02,
#  'JNE1977': 112.61,
#  'JNE1998': 183.4,
#  'JNE2006': 180.2,
#  'JNE2009': 189.6,
#  'JNE2014': 191.89,
#  'JNE2032': 114.83,
#  'JNE2049': 197.32,
#  'JNE2086': 370.95,
#  'JNE2100': 134.82,
#  'JNE2101': 141.4,
#  'JNE2113': 329.22,
#  'JNE2131': 392.46,
#  'JNE2132': 243.46,
#  'JNE2145': 259.65,
#  'JNE2153': 148.42,
#  'JNE2170': 317.64,
#  'JNE2171': 262.44,
#  'JNE2199': 190.29,
#  'JNE2205': 173.53,
#  'JNE2209': 190.02,
#  'JNE2251': 216.96,
#  'JNE2262': 223.02,
#  'JNE2265': 174.67,
#  'JNE2266': 176.95,
#  'JNE2270': 353.23,
#  'JNE2291': 133.73,
#  'JNE2292': 161.11,
#  'JNE2293': 217.07,
#  'JNE2294': 356.86,
#  'JNE2300': 351.27,
#  'JNE2302': 186.85,
#  'JNE2305': 194.84,
#  'JNE2307': 127.73,
#  'JNE2309': 235.68,
#  'JNE2321': 415.04,
#  'JNE2323': 227.97,
#  'JNE2324': 295.62,
#  'JNE3030': 376.59,
#  'JNE3042': 112.69,
#  'JNE3062': 284.68,
#  'JNE3065': 150.66,
#  'JNE3068': 421.58,
#  'JNE3144': 236.65,
#  'JNE3157': 261.74,
#  'JNE3160': 465.87,
#  'JNE3220': 319.73,
#  'JNE3225': 210.7,
#  'JNE3234': 249.9,
#  'JNE3251': 182.29,
#  'JNE3252': 174.76,
#  'JNE3253': 191.49,
#  'JNE3255': 224.88,
#  'JNE3256': 178.82,
#  'JNE3257': 220.92,
#  'JNE3261': 215.47,
#  'JNE3265': 192.97,
#  'JNE3270': 157.47,
#  'JNE3273': 302.67,
#  'JNE3276': 100.86,
#  'JNE3279': 173.67,
#  'JNE3281': 185.22,
#  'JNE3284': 137.57,
#  'JNE3288': 155.27,
#  'JNE3291': 220.94,
#  'JNE3294': 265.42,
#  'JNE3296': 237.69,
#  'JNE3311': 247.85,
#  'JNE3313': 258.42,
#  'JNE3323': 162.2,
#  'JNE3334': 141.79,
#  'JNE3336': 168.54,
#  'JNE3338': 61.04,
#  'JNE3339': 192.93,
#  'JNE3342': 221.7,
#  'JNE3344': 193.6,
#  'JNE3346': 182.93,
#  'JNE3348': 243.18,
#  'JNE3351': 164.98,
#  'JNE3355': 275.44,
#  'JNE3359': 177.2,
#  'JNE3360': 119.06,
#  'JNE3362': 244.43,
#  'JNE3363': 238.68,
#  'JNE3364': 193.4,
#  'JNE3365': 217.31,
#  'JNE3366': 246.73,
#  'JNE3368': 199.42,
#  'JNE3369': 204.17,
#  'JNE3370': 193.53,
#  'JNE3371': 207.13,
#  'JNE3373': 189.77,
#  'JNE3375': 159.74,
#  'JNE3376': 185.99,
#  'JNE3383': 230.78,
#  'JNE3384': 200.08,
#  'JNE3386': 187.62,
#  'JNE3387': 331.96,
#  'JNE3388': 189.15,
#  'JNE3389': 324.78,
#  'JNE3390': 129.29,
#  'JNE3391': 174.17,
#  'JNE3394': 192.32,
#  'JNE3395': 173.37,
#  'JNE3396': 286.8,
#  'JNE3398': 139.7,
#  'JNE3399': 251.64,
#  'JNE3400': 307.16,
#  'JNE3401': 155.04,
#  'JNE3402': 269.36,
#  'JNE3403': 182.25,
#  'JNE3404': 226.78,
#  'JNE3405': 190.34,
#  'JNE3407': 113.87,
#  'JNE3408': 254.07,
#  'JNE3409': 161.26,
#  'JNE3412': 249.17,
#  'JNE3413': 294.94,
#  'JNE3415': 188.52,
#  'JNE3416': 128.87,
#  'JNE3417': 166.99,
#  'JNE3420': 129.92,
#  'JNE3421': 174.43,
#  'JNE3422': 126.46,
#  'JNE3423': 173.82,
#  'JNE3424': 138.49,
#  'JNE3425': 151.37,
#  'JNE3426': 203.1,
#  'JNE3427': 94.39,
#  'JNE3428': 173.74,
#  'JNE3429': 146.07,
#  'JNE3430': 144.38,
#  'JNE3431': 136.33,
#  'JNE3432': 269.02,
#  'JNE3434': 157.83,
#  'JNE3435': 308.3,
#  'JNE3436': 205.96,
#  'JNE3437': 214.35,
#  'JNE3438': 224.31,
#  'JNE3439': 196.12,
#  'JNE3440': 275.8,
#  'JNE3441': 170.49,
#  'JNE3442': 183.24,
#  'JNE3443': 198.87,
#  'JNE3445': 236.12,
#  'JNE3446': 140.17,
#  'JNE3447': 185.25,
#  'JNE3449': 207.26,
#  'JNE3450': 194.21,
#  'JNE3451': 238.72,
#  'JNE3452': 175.45,
#  'JNE3453': 170.38,
#  'JNE3454': 220.72,
#  'JNE3455': 308.32,
#  'JNE3456': 106.43,
#  'JNE3457': 182.09,
#  'JNE3458': 206.31,
#  'JNE3459': 270.68,
#  'JNE3460': 245.74,
#  'JNE3461': 151.22,
#  'JNE3463': 224.5,
#  'JNE3464': 375.24,
#  'JNE3465': 263.58,
#  'JNE3466': 415.88,
#  'JNE3467': 141.36,
#  'JNE3468': 240.22,
#  'JNE3470': 111.45,
#  'JNE3471': 141.78,
#  'JNE3472': 164.51,
#  'JNE3473': 266.75,
#  'JNE3474': 211.44,
#  'JNE3475': 129.61,
#  'JNE3476': 227.2,
#  'JNE3477': 216.53,
#  'JNE3479': 158.39,
#  'JNE3480': 107.9,
#  'JNE3481': 191.68,
#  'JNE3482': 181.84,
#  'JNE3483': 241.69,
#  'JNE3484': 128.46,
#  'JNE3485': 241.45,
#  'JNE3486': 137.99,
#  'JNE3487': 128.49,
#  'JNE3488': 111.42,
#  'JNE3489': 321.2,
#  'JNE3491': 252.54,
#  'JNE3500': 176.18,
#  'JNE3501': 142.58,
#  'JNE3503': 129.41,
#  'JNE3504': 167.61,
#  'JNE3506': 329.45,
#  'JNE3507': 153.84,
#  'JNE3510': 224.86,
#  'JNE3515': 180.14,
#  'JNE3516': 134.36,
#  'JNE3517': 161.57,
#  'JNE3518': 283.13,
#  'JNE3520': 269.59,
#  'JNE3522': 122.9,
#  'JNE3523': 185.34,
#  'JNE3524': 230.09,
#  'JNE3526': 162.83,
#  'JNE3528': 152.0,
#  'JNE3530': 182.79,
#  'JNE3531': 161.38,
#  'JNE3532': 170.74,
#  'JNE3534': 132.79,
#  'JNE3535': 263.17,
#  'JNE3537': 180.13,
#  'JNE3538': 185.16,
#  'JNE3539': 171.46,
#  'JNE3541': 141.61,
#  'JNE3542': 128.11,
#  'JNE3543': 185.68,
#  'JNE3544': 222.18,
#  'JNE3545': 117.26,
#  'JNE3546': 213.99,
#  'JNE3547': 245.49,
#  'JNE3548': 308.69,
#  'JNE3549': 111.19,
#  'JNE3550': 134.9,
#  'JNE3553': 211.07,
#  'JNE3554': 228.83,
#  'JNE3555': 226.81,
#  'JNE3556': 195.09,
#  'JNE3557': 254.32,
#  'JNE3558': 169.67,
#  'JNE3559': 232.2,
#  'JNE3560': 236.35,
#  'JNE3561': 204.41,
#  'JNE3562': 305.03,
#  'JNE3563': 197.49,
#  'JNE3564': 277.3,
#  'JNE3565': 124.87,
#  'JNE3566': 240.62,
#  'JNE3567': 219.41,
#  'JNE3568': 193.86,
#  'JNE3570': 210.79,
#  'JNE3571': 179.78,
#  'JNE3573': 191.78,
#  'JNE3574': 211.93,
#  'JNE3575': 169.42,
#  'JNE3576': 266.99,
#  'JNE3577': 412.44,
#  'JNE3578': 274.93,
#  'JNE3579': 156.89,
#  'JNE3581': 368.59,
#  'JNE3601': 186.06,
#  'JNE3602': 178.22,
#  'JNE3603': 202.58,
#  'JNE3605': 287.77,
#  'JNE3606': 199.12,
#  'JNE3607': 197.4,
#  'JNE3608': 219.59,
#  'JNE3609': 344.23,
#  'JNE3610': 146.91,
#  'JNE3611': 207.57,
#  'JNE3612': 256.47,
#  'JNE3613': 163.25,
#  'JNE3614': 255.3,
#  'JNE3615': 128.26,
#  'JNE3616': 203.64,
#  'JNE3617': 153.51,
#  'JNE3618': 201.1,
#  'JNE3619': 189.72,
#  'JNE3620': 143.6,
#  'JNE3621': 306.48,
#  'JNE3622': 190.33,
#  'JNE3623': 138.88,
#  'JNE3624': 275.19,
#  'JNE3625': 225.62,
#  'JNE3627': 143.63,
#  'JNE3628': 293.66,
#  'JNE3629': 270.62,
#  'JNE3630': 191.52,
#  'JNE3631': 251.1,
#  'JNE3633': 285.23,
#  'JNE3634': 355.39,
#  'JNE3635': 219.77,
#  'JNE3636': 290.34,
#  'JNE3637': 293.53,
#  'JNE3638': 240.41,
#  'JNE3639': 298.29,
#  'JNE3640': 296.38,
#  'JNE3641': 247.66,
#  'JNE3642': 147.18,
#  'JNE3643': 148.65,
#  'JNE3644': 149.32,
#  'JNE3645': 162.48,
#  'JNE3647': 157.62,
#  'JNE3648': 274.55,
#  'JNE3649': 163.52,
#  'JNE3651': 288.27,
#  'JNE3652': 178.3,
#  'JNE3653': 186.64,
#  'JNE3654': 153.07,
#  'JNE3655': 149.28,
#  'JNE3656': 281.67,
#  'JNE3657': 177.1,
#  'JNE3658': 148.18,
#  'JNE3659': 187.35,
#  'JNE3660': 227.33,
#  'JNE3661': 191.66,
#  'JNE3662': 278.04,
#  'JNE3663': 197.04,
#  'JNE3665': 362.89,
#  'JNE3666': 133.98,
#  'JNE3667': 154.82,
#  'JNE3668': 340.96,
#  'JNE3669': 269.5,
#  'JNE3670': 268.57,
#  'JNE3671': 327.1,
#  'JNE3672': 260.1,
#  'JNE3673': 310.42,
#  'JNE3674': 298.78,
#  'JNE3675': 309.64,
#  'JNE3676': 236.92,
#  'JNE3678': 286.48,
#  'JNE3679': 164.07,
#  'JNE3680': 269.89,
#  'JNE3683': 176.58,
#  'JNE3684': 165.34,
#  'JNE3686': 267.46,
#  'JNE3687': 350.4,
#  'JNE3688': 419.35,
#  'JNE3689': 295.76,
#  'JNE3690': 298.55,
#  'JNE3691': 433.16,
#  'JNE3693': 203.34,
#  'JNE3694': 189.99,
#  'JNE3695': 200.25,
#  'JNE3697': 310.94,
#  'JNE3698': 188.19,
#  'JNE3700': 161.6,
#  'JNE3701': 156.41,
#  'JNE3702': 185.37,
#  'JNE3703': 143.78,
#  'JNE3704': 259.69,
#  'JNE3706': 198.91,
#  'JNE3707': 241.12,
#  'JNE3708': 327.99,
#  'JNE3709': 467.63,
#  'JNE3710': 342.34,
#  'JNE3712': 316.13,
#  'JNE3713': 201.07,
#  'JNE3714': 219.26,
#  'JNE3715': 142.23,
#  'JNE3716': 154.07,
#  'JNE3717': 162.74,
#  'JNE3718': 166.65,
#  'JNE3719': 254.39,
#  'JNE3720': 243.44,
#  'JNE3721': 193.73,
#  'JNE3722': 177.41,
#  'JNE3724': 181.93,
#  'JNE3725': 257.82,
#  'JNE3726': 202.74,
#  'JNE3727': 247.98,
#  'JNE3728': 199.49,
#  'JNE3729': 155.74,
#  'JNE3730': 188.61,
#  'JNE3732': 288.1,
#  'JNE3733': 228.24,
#  'JNE3734': 268.72,
#  'JNE3735': 252.54,
#  'JNE3736': 153.1,
#  'JNE3738': 182.62,
#  'JNE3739': 254.88,
#  'JNE3740': 148.63,
#  'JNE3741': 246.83,
#  'JNE3742': 258.68,
#  'JNE3743': 149.8,
#  'JNE3744': 403.76,
#  'JNE3745': 129.27,
#  'JNE3748': 279.95,
#  'JNE3749': 210.86,
#  'JNE3750': 303.13,
#  'JNE3751': 233.4,
#  'JNE3752': 215.64,
#  'JNE3753': 256.75,
#  'JNE3756': 281.12,
#  'JNE3757': 231.55,
#  'JNE3758': 215.55,
#  'JNE3759': 264.63,
#  'JNE3760': 264.54,
#  'JNE3761': 115.56,
#  'JNE3762': 216.67,
#  'JNE3763': 228.37,
#  'JNE3764': 230.38,
#  'JNE3765': 196.01,
#  'JNE3766': 310.41,
#  'JNE3767': 236.97,
#  'JNE3768': 283.25,
#  'JNE3769': 321.62,
#  'JNE3770': 226.81,
#  'JNE3771': 216.85,
#  'JNE3773': 165.84,
#  'JNE3774': 222.47,
#  'JNE3775': 138.89,
#  'JNE3776': 194.09,
#  'JNE3777': 144.79,
#  'JNE3778': 233.91,
#  'JNE3779': 165.8,
#  'JNE3780': 216.3,
#  'JNE3781': 149.33,
#  'JNE3782': 233.72,
#  'JNE3783': 262.18,
#  'JNE3784': 294.8,
#  'JNE3785': 224.21,
#  'JNE3786': 216.53,
#  'JNE3787': 285.11,
#  'JNE3788': 225.05,
#  'JNE3789': 190.4,
#  'JNE3790': 208.1,
#  'JNE3791': 200.37,
#  'JNE3792': 251.87,
#  'JNE3793': 193.11,
#  'JNE3794': 350.89,
#  'JNE3795': 284.45,
#  'JNE3796': 162.81,
#  'JNE3797': 258.69,
#  'JNE3798': 376.59,
#  'JNE3799': 309.63,
#  'JNE3800': 384.7,
#  'JNE3801': 266.9,
#  'JNE3802': 214.37,
#  'JNE3803': 219.14,
#  'JNE3804': 207.52,
#  'JNE3805': 319.34,
#  'JNE3806': 326.04,
#  'JNE3807': 332.84,
#  'JNE3810': 297.36,
#  'JNE3811': 292.29,
#  'JNE3813': 237.07,
#  'JNE3816': 210.42,
#  'JNE3817': 196.36,
#  'JNE3818': 261.5,
#  'JNE3819': 282.93,
#  'JNE3820': 207.37,
#  'JNE3821': 240.32,
#  'JNE3822': 285.09,
#  'JNE3823': 183.0,
#  'JNE3825': 224.64,
#  'JNE3833': 201.03,
#  'JNE3834': 209.72,
#  'JNE3835': 286.06,
#  'JNE3836': 264.42,
#  'JNE3837': 356.14,
#  'JNE3838': 190.43,
#  'JNE3856': 414.53,
#  'JNE3860': 433.78,
#  'JNE3861': 557.71,
#  'JNE3862': 340.1,
#  'JNE3863': 311.58,
#  'JNE3864': 365.67,
#  'JNE3865': 348.65,
#  'JNE3866': 464.79,
#  'JNE3869': 508.35,
#  'JNE3870': 390.63,
#  'JNE3871': 294.2,
#  'JNE3872': 359.12,
#  'JNE3875': 412.66,
#  'JNE3878': 165.72,
#  'JNE3879': 382.45,
#  'JNE3880': 347.4,
#  'JNE3881': 486.88,
#  'JNE3885': 314.75,
#  'JNE3886': 266.58,
#  'JNE3887': 243.54,
#  'JNE3888': 310.01,
#  'JNE3889': 451.26,
#  'JNE3890': 404.94,
#  'JNE3891': 390.61,
#  'JNE3892': 265.17,
#  'JNE3893': 384.5,
#  'JNE3894': 390.82,
#  'JNE3895': 353.49,
#  'JNE3896': 334.81,
#  'JNE3897': 226.67,
#  'JNE3898': 330.47,
#  'JNE3899': 300.07,
#  'JNE3900': 302.63,
#  'JNE3902': 262.94,
#  'JNE3903': 198.32,
#  'JNE3904': 226.79,
#  'JNE3905': 383.69,
#  'JNE3906': 451.65,
#  'JNE3907': 538.55,
#  'JNE3908': 415.86,
#  'JNE3909': 410.67,
#  'JNE3910': 475.33,
#  'JNE3924': 342.57,
#  'JNE3927': 508.69,
#  'JNE3928': 317.01,
#  'MEN5001': 354.05,
#  'MEN5002': 285.58,
#  'MEN5003': 253.54,
#  'MEN5004': 303.05,
#  'MEN5005': 194.66,
#  'MEN5006': 275.91,
#  'MEN5007': 204.43,
#  'MEN5008': 349.6,
#  'MEN5009': 258.44,
#  'MEN5010': 282.18,
#  'MEN5011': 350.52,
#  'MEN5012': 310.27,
#  'MEN5013': 274.31,
#  'MEN5014': 212.66,
#  'MEN5015': 324.6,
#  'MEN5016': 280.27,
#  'MEN5017': 236.86,
#  'MEN5018': 231.52,
#  'MEN5019': 212.1,
#  'MEN5020': 201.85,
#  'MEN5021': 369.94,
#  'MEN5022': 327.91,
#  'MEN5023': 380.36,
#  'MEN5024': 239.73,
#  'MEN5025': 383.28,
#  'MEN5026': 287.09,
#  'MEN5027': 230.33,
#  'MEN5028': 345.77,
#  'MEN5029': 305.09,
#  'MEN5030': 250.99,
#  'MEN5031': 215.46,
#  'MEN5032': 321.86,
#  'NW001': 219.46,
#  'NW002': 262.65,
#  'NW003': 183.41,
#  'NW004': 237.96,
#  'NW005': 316.26,
#  'NW006': 249.46,
#  'NW007': 204.25,
#  'NW008': 201.84,
#  'NW009': 229.97,
#  'NW012': 306.46,
#  'NW013': 243.11,
#  'NW014': 371.84,
#  'NW015': 283.04,
#  'NW016': 344.25,
#  'NW020': 202.45,
#  'NW022': 328.3,
#  'NW023': 406.82,
#  'NW024': 207.19,
#  'NW027': 372.44,
#  'NW028': 321.03,
#  'NW029': 185.85,
#  'NW030': 243.83,
#  'NW031': 273.89,
#  'NW032': 257.05,
#  'NW033': 228.76,
#  'NW034': 373.55,
#  'NW035': 369.68,
#  'NW036': 289.53,
#  'NW037': 171.27,
#  'NW038': 305.55,
#  'NW039': 213.47,
#  'PJ0096': 388.19,
#  'PJNE1906': 467.8,
#  'PJNE2014': 253.27,
#  'PJNE2100': 395.58,
#  ...}

# %%
ecommerce_A_data['cost_per_unit'] = ecommerce_A_data['style'].map(style_to_cost)

# %%
ecommerce_A_data
# Out:
#                            date                        status fulfilment  \
# 0       2022-04-15 00:00:00.000  Shipped - Delivered to Buyer   Merchant
# 1       2022-04-15 00:00:00.000                       Shipped     Amazon
# 2       2022-04-15 00:00:00.000                       Shipped     Amazon
# 3       2022-04-15 00:00:00.000                       Shipped     Amazon
# 4       2022-04-15 00:00:00.000                       Shipped     Amazon
# ...                         ...                           ...        ...
# 110532  2022-04-15 00:00:00.000                       Shipped     Amazon
# 110533  2022-04-15 00:00:00.000                       Shipped     Amazon
# 110534  2022-04-13 00:00:00.000                       Shipped     Amazon
# 110535  2022-04-13 00:00:00.000                       Shipped     Amazon
# 110536  2022-04-13 00:00:00.000                       Shipped     Amazon
#
#        sales_channel_  amount  qty       category               size    style  \
# 0           Amazon.in   442.0    1          kurta       JNE3510-KR-M  JNE3510
# 1           Amazon.in   376.0    1          kurta  JNE3366-KR-1053-M  JNE3366
# 2           Amazon.in   471.0    1          kurta       JNE3368-KR-M  JNE3368
# 3           Amazon.in   523.0    1            Set      NW015-TP-PJ-S    NW015
# 4           Amazon.in   788.0    1            Set    SET268-KR-NP-XS   SET268
# ...               ...     ...  ...            ...                ...      ...
# 110532      Amazon.in   612.0    1            Set    SET044-KR-NP-XS   SET044
# 110533      Amazon.in   488.0    1  Western Dress         J0171-DR-M    J0171
# 110534      Amazon.in   399.0    1          kurta      JNE3405-KR-XS  JNE3405
# 110535      Amazon.in   725.0    1  Western Dress      JNE3797-KR-XL  JNE3797
# 110536      Amazon.in   399.0    1          kurta      JNE3405-KR-XS  JNE3405
#
#               ship_city    ship_state  ship_postal_code  cost_per_unit
# 0                 KORBA  CHHATTISGARH          495450.0         224.86
# 1           TIRUNELVELI    TAMIL NADU          627416.0         246.73
# 2           TIRUNELVELI    TAMIL NADU          627416.0         199.42
# 3                 AJMER     RAJASTHAN          305001.0         283.04
# 4             NEW DELHI         DELHI          110019.0         471.50
# ...                 ...           ...               ...            ...
# 110532        HYDERABAD     TELANGANA          500084.0         334.06
# 110533        HYDERABAD     TELANGANA          500080.0         228.06
# 110534           MUMBAI   MAHARASHTRA          400051.0         190.34
# 110535  TIRUCHIRAPPALLI    TAMIL NADU          620001.0         258.69
# 110536         JHALAWAR     RAJASTHAN          326512.0         190.34
#
# [110537 rows x 13 columns]

# %%
ecommerce_A_data.to_sql(
    name = 'ecommerce_data',
    if_exists="replace",
    schema=pg_schema,
    con=engine
)
# Out:
# 537
